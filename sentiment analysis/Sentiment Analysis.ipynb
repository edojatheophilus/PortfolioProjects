# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data into a Pandas dataframe
data = pd.read_csv('sentiment_analysis_data.csv')

# %%
data
# Out:
#                              Date  \
# 0       2023-02-12 23:59:59+00:00
# 1       2023-02-12 23:59:59+00:00
# 2       2023-02-12 23:59:59+00:00
# 3       2023-02-12 23:59:59+00:00
# 4       2023-02-12 23:59:59+00:00
# ...                           ...
# 305948  2023-02-12 00:00:00+00:00
# 305949  2023-02-12 00:00:00+00:00
# 305950  2023-02-12 00:00:00+00:00
# 305951  2023-02-12 00:00:00+00:00
# 305952  2023-02-12 00:00:00+00:00
#
#                                                     Tweet  Likes  \
# 0          go shoot super bowl chiefsvseagl superbowllvii      0
# 1                     anyon gon na play defens super bowl      0
# 2       earn stadium beer badg untappd superbowl footb...      0
# 3                got phi win superbowl eaglesvschief eagl      0
# 4                  lil concern eagl defens heel superbowl      0
# ...                                                   ...    ...
# 305948  live super bowl squar pic ili tombradi superbo...      1
# 305949  let honest super bowl realli food get rib tip ...      3
# 305950  two commerci jesus schedul air sunday super bo...      1
# 305951  anoth year wherein success make super bowl wee...     48
# 305952  superbowl weekend game arizona year shock repu...    172
#
#                                                      Link Sentiment
# 0       https://twitter.com/diaryofabbw21/status/16249...  Positive
# 1       https://twitter.com/jakeisapersonik/status/162...  Positive
# 2       https://twitter.com/mildandlazyguy/status/1624...  Positive
# 3       https://twitter.com/Blackmartian333/status/162...  Positive
# 4       https://twitter.com/Marilyn_Renee/status/16249...  Positive
# ...                                                   ...       ...
# 305948  https://twitter.com/a_bag_of_lambs/status/1624...  Positive
# 305949  https://twitter.com/WBEZreset/status/162455890...  Positive
# 305950  https://twitter.com/RICatholic/status/16245589...  Positive
# 305951  https://twitter.com/coolauntV/status/162455890...  Positive
# 305952  https://twitter.com/RealTimers/status/16245589...  Positive
#
# [305953 rows x 5 columns]

# %%
# Check the data types and missing values
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305953 entries, 0 to 305952
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       305953 non-null  object
#  1   Tweet      305936 non-null  object
#  2   Likes      305953 non-null  int64
#  3   Link       305953 non-null  object
#  4   Sentiment  305953 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 11.7+ MB
# None

# %%
data = data.dropna(subset=['Tweet'])

# %%
# Visualize the distribution of sentiment labels
sns.countplot(x='Sentiment', data=data)
plt.show()

# %%
# Create a word cloud of the most common words in the tweets
from wordcloud import WordCloud
wordcloud = WordCloud(background_color='white').generate(' '.join(data['Tweet']))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
